# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasBorgesKrz/the-walking-dead-project/blob/main/gerador_de_post_twd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image, ImageDraw, ImageFont
import urllib.request
imagem = Image.open('rick.jpg')
desenhista = ImageDraw.Draw(imagem)
url_fonte = "https://github.com/google/fonts/raw/main/ofl/anton/Anton-Regular.ttf"
urllib.request.urlretrieve(url_fonte, "Anton-Regular.ttf")
tamanho_da_letra = 180
fonte_oficial = ImageFont.truetype("Anton-Regular.ttf", tamanho_da_letra)
x = int(imagem.width * 0.05)
y = int(imagem.height - tamanho_da_letra - 80)
desenhista.text((x + 8, y + 8), texto, fill="black", font=fonte_oficial)
imagem.save('rick_poster_oficial.jpg')
display(imagem)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2000x1270>
